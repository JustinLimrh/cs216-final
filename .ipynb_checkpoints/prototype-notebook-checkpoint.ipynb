# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sns.set_theme()
import yahoofinance_data_grabber as yhf

# %%
df_clean = pd.read_csv("datasets/covid_19_clean_complete.csv")
df_daywise = pd.read_csv("datasets/day_wise.csv")
index_list = ['^GSPC', '^VIX', '^N225', '000001.SS', '^KS11', '^STOXX50E']
data_list = yhf.grab_index_data(index_list)

# %%
SnP_500 = data_list[0]
VIX = data_list[1]
Nikkei = data_list[2]
Shanghai_SSE = data_list[3]
Korean_KOSPI = data_list[4]
STOXX50E = data_list[5]

# %%
SnP_500_merged = SnP_500.merge(df_daywise, right_on = "Date", left_on = "formatted_date", how = "right")
SnP_500_merged
# Out:
#             high          low         open        close        volume  \
# 0    3337.770020  3320.040039  3330.020020  3321.750000  3.619850e+09
# 1    3326.879883  3301.870117  3315.770020  3325.540039  3.764860e+09
# 2    3333.179932  3281.530029  3333.100098  3295.469971  3.707130e+09
# 3            NaN          NaN          NaN          NaN           NaN
# 4            NaN          NaN          NaN          NaN           NaN
# ..           ...          ...          ...          ...           ...
# 183  3279.989990  3222.659912  3271.639893  3235.659912  4.290460e+09
# 184  3227.260010  3200.050049  3218.580078  3215.629883  3.894900e+09
# 185          NaN          NaN          NaN          NaN           NaN
# 186          NaN          NaN          NaN          NaN           NaN
# 187  3241.429932  3214.250000  3219.840088  3239.409912  3.963910e+09
#
#         adjclose        Date  Confirmed  Deaths  Recovered   Active  \
# 0    3321.750000  2020-01-22        555      17         28      510
# 1    3325.540039  2020-01-23        654      18         30      606
# 2    3295.469971  2020-01-24        941      26         36      879
# 3            NaN  2020-01-25       1434      42         39     1353
# 4            NaN  2020-01-26       2118      56         52     2010
# ..           ...         ...        ...     ...        ...      ...
# 183  3235.659912  2020-07-23   15510481  633506    8710969  6166006
# 184  3215.629883  2020-07-24   15791645  639650    8939705  6212290
# 185          NaN  2020-07-25   16047190  644517    9158743  6243930
# 186          NaN  2020-07-26   16251796  648621    9293464  6309711
# 187  3239.409912  2020-07-27   16480485  654036    9468087  6358362
#
#      New cases  New deaths  New recovered  Deaths / 100 Cases  \
# 0            0           0              0                3.06
# 1           99           1              2                2.75
# 2          287           8              6                2.76
# 3          493          16              3                2.93
# 4          684          14             13                2.64
# ..         ...         ...            ...                 ...
# 183     282756        9966         169714                4.08
# 184     281164        6144         228736                4.05
# 185     255545        4867         219038                4.02
# 186     204606        4104         134721                3.99
# 187     228693        5415         174623                3.97
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  No. of countries
# 0                     5.05                   60.71                 6
# 1                     4.59                   60.00                 8
# 2                     3.83                   72.22                 9
# 3                     2.72                  107.69                11
# 4                     2.46                  107.69                13
# ..                     ...                     ...               ...
# 183                  56.16                    7.27               187
# 184                  56.61                    7.16               187
# 185                  57.07                    7.04               187
# 186                  57.18                    6.98               187
# 187                  57.45                    6.91               187
#
# [188 rows x 18 columns]

# %%
SnP_plot = sns.relplot(x='Date', y='close', kind="line", data=SnP_500_merged)
SnP_plot.set(xticklabels=[])

# %%
new_cases_plot = sns.relplot(x='Date', y='New cases', kind="line", data=SnP_500_merged)
new_cases_plot.set(xticklabels=[])
